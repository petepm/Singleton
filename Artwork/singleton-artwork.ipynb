# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn
seaborn.set()

# %%
plt.xkcd()

# %%
x = np.linspace(0, 5, num=100)
# x = np.array((0, 0.6, 6.6, 66.6))
y = np.exp(x)
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(x, y, lw=3, label="$H$")
ax.plot(x, y, lw=3, label=r"$\frac{\partial H}{\partial t}$", linestyle="dashed")
ax.set_xlabel("Pete Peterson")
ax.set_ylabel("Singleton")
ax.legend()
